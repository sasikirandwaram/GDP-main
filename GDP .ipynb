# %%
import pandas as pd

# %%
gdp_current_year=pd.read_csv("D:\CSV\Gross Domestic Product (GDP) at Current Price.csv")
gdp_current_year
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 3       (% Growth over previous year)  2016-17           14.65
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
# 5  GSDP - CURRENT PRICES (` in Crore)  2012-13       411404.00
# 6  GSDP - CURRENT PRICES (` in Crore)  2013-14       464272.00
# 7  GSDP - CURRENT PRICES (` in Crore)  2014-15       526468.00
# 8  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
# 9  GSDP - CURRENT PRICES (` in Crore)  2016-17       699307.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# ...

# %%
#draw in pivot to show the data in better way

# %%
pd.pivot_table(gdp_current_year,index=['Items Description','Duration'])
# Out:
#                                              All_India GDP  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
#                                    2016-17           11.52
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#                                    2016-17     15251028.00
#
#                                              Andaman & Nicobar Islands  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14                       16.68
#                                    2014-15                       10.89
# ...

# %%
gdp_current_price=gdp_current_year.drop(gdp_current_year.index[[3,9]])   #dropping the Nan rows
gdp_current_price
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
# 5  GSDP - CURRENT PRICES (` in Crore)  2012-13       411404.00
# 6  GSDP - CURRENT PRICES (` in Crore)  2013-14       464272.00
# 7  GSDP - CURRENT PRICES (` in Crore)  2014-15       526468.00
# 8  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# 2              12.07      13.19      10.59         10.98     10.75      11.09
# 4           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# ...

# %%
gdp_current_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 8
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items Description          8 non-null      object
#  1   Duration                   8 non-null      object
#  2   Andhra Pradesh             8 non-null      float64
#  3   Arunachal Pradesh          8 non-null      float64
#  4   Assam                      8 non-null      float64
#  5   Bihar                      8 non-null      float64
#  6   Chhattisgarh               8 non-null      float64
#  7   Goa                        8 non-null      float64
#  8   Gujarat                    8 non-null      float64
#  9   Haryana                    8 non-null      float64
#  10  Himachal Pradesh           6 non-null      float64
#  11  Jammu & Kashmir            8 non-null      float64
#  12  Jharkhand                  8 non-null      float64
# ...

# %%
#index_to_drop=gdp_current_price.index[((gdp_current_price["Items Description"]=='(% Growth over previous year)')
  #                                     &(gdp_current_price["Duration"]=="2016-17"))]

# %%
#gdp_current_price.drop(index_to_drop) #we can try this also for droping null row

# %%
gdp_current_price.columns    #names of the col/states
# Out:
# Index(['Items Description', 'Duration', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal1', 'Andaman & Nicobar Islands', 'Chandigarh', 'Delhi',
#        'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
col_att=list(gdp_current_price.columns)
del(col_att[0])      #to delete Items Description
del(col_att[0])    #to delete duration
states=col_att
states
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
State_mean={}
for column in gdp_current_price:   #column =i (key)
    if column in states:
        mean=gdp_current_price[gdp_current_price["Items Description"]=="(% Growth over previous year)"][column].mean()
        State_mean[column]=mean
State_mean["Items Description"]="Average growth rate"
gdp_current_price=gdp_current_price.append(State_mean,ignore_index=True)
gdp_current_price
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14       12.850000
# 1       (% Growth over previous year)  2014-15       13.400000
# 2       (% Growth over previous year)  2015-16       15.850000
# 3  GSDP - CURRENT PRICES (` in Crore)  2011-12   379402.000000
# 4  GSDP - CURRENT PRICES (` in Crore)  2012-13   411404.000000
# 5  GSDP - CURRENT PRICES (` in Crore)  2013-14   464272.000000
# 6  GSDP - CURRENT PRICES (` in Crore)  2014-15   526468.000000
# 7  GSDP - CURRENT PRICES (` in Crore)  2015-16   609934.000000
# 8                 Average growth rate      NaN       14.033333
#
#    Arunachal Pradesh      Assam          Bihar   Chhattisgarh           Goa  \
# 0          16.380000      13.31      12.300000      16.440000     -5.770000
# 1          14.790000      11.45      17.920000      13.690000     13.120000
# 2          12.070000      13.19      10.590000      10.980000     10.750000
# ...

# %%
gdp_current_price=gdp_current_price.iloc[[2,7,8]]   #2,7,8 rows only want currently to focus #too many indexs
gdp_current_price
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 2       (% Growth over previous year)  2015-16       15.850000
# 7  GSDP - CURRENT PRICES (` in Crore)  2015-16   609934.000000
# 8                 Average growth rate      NaN       14.033333
#
#    Arunachal Pradesh      Assam          Bihar   Chhattisgarh           Goa  \
# 2          12.070000      13.19      10.590000      10.980000     10.750000
# 7       18784.000000  224234.00  413503.000000  260776.000000  45002.000000
# 8          14.413333      12.65      13.603333      13.703333      6.033333
#
#          Gujarat        Haryana  ...      Telangana  Tripura  Uttar Pradesh  \
# 2      11.090000      10.910000  ...      12.610000      NaN          10.58
# 7  994316.000000  485184.000000  ...  575631.000000      NaN     1153795.00
# 8      11.126667      11.846667  ...      12.763333    17.03          11.94
#
#      Uttarakhand  West Bengal1  Andaman & Nicobar Islands  Chandigarh  \
# ...

# %%
gdp=gdp_current_price.T  #for making graph making obiective to variable by using transpose
gdp
# Out:
#                                                        2  \
# Items Description          (% Growth over previous year)
# Duration                                         2015-16
# Andhra Pradesh                                     15.85
# Arunachal Pradesh                                  12.07
# Assam                                              13.19
# Bihar                                              10.59
# Chhattisgarh                                       10.98
# Goa                                                10.75
# Gujarat                                            11.09
# Haryana                                            10.91
# Himachal Pradesh                                     NaN
# Jammu & Kashmir                                    17.91
# Jharkhand                                          11.44
# Karnataka                                          11.42
# Kerala                                             11.85
# ...

# %%
gdp.columns=gdp.iloc[0]
gdp=gdp.drop(gdp.index[0:2])    #dropping the rows
#gdp=gdp[1:]                   # start from index 1
gdp
# Out:
# Items Description         (% Growth over previous year)  \
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# ...

# %%
gdp["Average growth rate"].sort_values()
# Out:
# Goa                          6.03333
# Meghalaya                    6.95333
# Odisha                       9.83667
# Sikkim                       10.4867
# Jammu & Kashmir                 10.9
# Gujarat                      11.1267
# Punjab                        11.185
# All_India GDP                11.2033
# Maharashtra                    11.26
# Rajasthan                      11.32
# Jharkhand                       11.5
# Uttarakhand                  11.8033
# Haryana                      11.8467
# Uttar Pradesh                  11.94
# Chandigarh                     11.96
# Puducherry                   12.0533
# Delhi                          12.16
# Himachal Pradesh               12.28
# Tamil Nadu                   12.3367
# Kerala                       12.5833
# Madhya Pradesh               12.6267
# Assam                          12.65
# Telangana                    12.7633
# Bihar                        13.6033
# Chhattisgarh                 13.7033
# ...

# %%
# make bar plot of Average growth rate    
import seaborn as sns
sns.barplot(gdp["Average growth rate"],gdp["Average growth rate"].index)

# %%
gdp["Average growth rate"].sort_values().plot.bar() # the easy way of making bar plot

# %%
gdp["GSDP - CURRENT PRICES (` in Crore)"].drop("All_India GDP").sort_values().plot.bar()

# %%
states2=['Andhra_Pradesh',
 'Arunachal_Pradesh',
 'Assam',
 'Bihar',
 'Chhattisgarh',
 'Goa',
 'Gujarat',
 'Haryana',
 'Himachal_Pradesh',
 'Jammu_Kashmir',
 'Jharkhand',
 'Karnataka',
 'Kerala',
 'Madhya_Pradesh',
 'Maharashtra',
 'Manipur',
 'Meghalaya',
 'Mizoram',
 'Nagaland',
 'Odisha',
 'Punjab',
 'Rajasthan',
 'Sikkim',
 'Tamil_Nadu',
 'Telangana',
 'Tripura',
 'Uttar_Pradesh',
 'Uttarakhand',
 'West_Bengal1']

# %%
len(states2)
# Out:
# 29

# %%
import os              #to iterate more csv
gsva=pd.DataFrame()
path="D:\CSV\Gsva\\"        
list_of_files=os.listdir(path)

# %%
len(list_of_files)
# Out:
# 29

# %%
for filename in list_of_files:
    for statename in states2:
        if statename in filename:
            filepath=path+filename
            data=pd.read_csv(filepath,encoding="ISO-8859-1")
            data=data[["Item","2014-15"]]
            data=data.T
            data.columns=data.iloc[0]
            data=data[1:]
            data["state"]=statename
            gsva=pd.concat([data,gsva])

# %%
gsva.set_index("state",inplace=True)

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
gsva.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
gsva["Primary_gdp_percent"]=0
gsva["Secondary_gdp_percent"]=0
gsva["tertary_gdp_percent"]=0

for i in range(len(gsva)):
    
    gsva.iloc[i,37]=gsva.iloc[i,6]/gsva.iloc[i,30]
    gsva.iloc[i,38]=gsva.iloc[i,10]/gsva.iloc[i,30]
    gsva.iloc[i,39]=gsva.iloc[i,26]/gsva.iloc[i,30]

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
gsva[["Primary_gdp_percent","Secondary_gdp_percent","tertary_gdp_percent"]].plot.bar()

# %%
gsva.sort_values("Per Capita GSDP (Rs.)")[["Primary_gdp_percent","Secondary_gdp_percent","tertary_gdp_percent"]].plot(kind="bar",stacked=True)
#sort out denpends on per capita income

# %%
gsva.sort_values("Per Capita GSDP (Rs.)")["Population ('00)"].plot(kind="bar")

# %%
per_capita=gsva['Per Capita GSDP (Rs.)'].sort_values()
per_capita.quantile([0.2,0.5,0.8,1])
# Out:
# 0.2     62989
# 0.5     97292
# 0.8    152853
# 1.0    271793
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
per_capita.sort_values(ascending=False)
# Out:
# state
# Goa                  271793
# Sikkim               240274
# Haryana              164077
# Kerala               154778
# Uttarakhand          153076
# Maharashtra          152853
# Tamil_Nadu           146503
# Karnataka            145141
# Gujarat              141263
# Telangana            139035
# Punjab               126606
# Arunachal_Pradesh    112718
# Andhra_Pradesh       104977
# Nagaland              89607
# Chhattisgarh          86860
# Rajasthan             84837
# Tripura               77358
# Meghalaya             76228
# Jammu_Kashmir         75840
# Odisha                73979
# Madhya_Pradesh        62989
# Jharkhand             62091
# Assam                 60621
# Manipur               58442
# Uttar_Pradesh         49450
# Bihar                 33954
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
category1=["Goa","Sikkim","Haryana","Kerala","Uttarakhand"]

category2=["Maharashtra","Tamil_Nadu","Karnataka","Gujarat","Arunachal_Pradesh","Andhra_Pradesh"]

category3=["Nagaland","Chhattisgarh","Rajasthan","Tripura","Meghalaya","Jammu_Kashmir","Odisha","Madhya_Pradesh"]

category4=["Jharkhand","Jharkhand","Assam","Manipur","Uttar_Pradesh","Bihar"]

categories_col=['Agriculture, forestry and fishing',
       'Mining and quarrying', 'Manufacturing',
       'Electricity, gas, water supply & other utility services',
       'Construction','Trade, repair, hotels and restaurants',
       'Hotels & restaurants','Transport, storage, communication & services related to broadcasting',
       'Financial services','Real estate, ownership of dwelling & professional services',
       'Public administration', 'Other services', 'Tertiary',
       'TOTAL GSVA at basic prices', 'Taxes on Products','Subsidies on products']

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Tamil_Nadu                                 13064238      7297820      4693361
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# ...

# %%
agg=gsva.loc[category1,categories_col].sum()
agg
# Out:
# Agriculture, forestry and fishing                                        15993232.0
# Mining and quarrying                                                       833510.0
# Manufacturing                                                            19625045.0
# Electricity, gas, water supply & other utility services                   2434878.0
# Construction                                                             12607184.0
# Trade, repair, hotels and restaurants                                    15738265.0
# Hotels & restaurants                                                      1214445.0
# Transport, storage, communication & services related to broadcasting      7885253.0
# Financial services                                                        4321519.0
# Real estate, ownership of dwelling & professional services               15571552.0
# Public administration                                                     4150701.0
# ...

# %%
agg_gsdp=gsva.loc[category1,"Gross State Domestic Product"].sum()
agg_gsdp
# Out:
# 118129206.0

# %%
round(100*agg/agg_gsdp).sort_values(ascending=False).head().plot.bar()    #percentage

# %%
agg=gsva.loc[category2,categories_col].sum()
agg
# Out:
# Agriculture, forestry and fishing                                       7.003482e+07
# Mining and quarrying                                                    1.002750e+07
# Manufacturing                                                           9.431486e+07
# Electricity, gas, water supply & other utility services                 1.214608e+07
# Construction                                                            3.811048e+07
# Trade, repair, hotels and restaurants                                   5.219913e+07
# Hotels & restaurants                                                    5.184414e+06
# Transport, storage, communication & services related to broadcasting    3.165132e+07
# Financial services                                                      3.236870e+07
# Real estate, ownership of dwelling & professional services              8.194799e+07
# Public administration                                                   1.608133e+07
# ...

# %%
agg_gsdp=gsva.loc[category2,'Gross State Domestic Product'].sum()
agg_gsdp
# Out:
# 524473032.0

# %%
round(100*agg/agg_gsdp).sort_values(ascending=False).head().plot.bar()    #percentage

# %%
agg=gsva.loc[category3,categories_col].sum()
agg
# Out:
# Agriculture, forestry and fishing                                        45012814.0
# Mining and quarrying                                                     10994877.0
# Manufacturing                                                            22619626.0
# Electricity, gas, water supply & other utility services                   5195006.0
# Construction                                                             16098458.0
# Trade, repair, hotels and restaurants                                    19145040.0
# Hotels & restaurants                                                      1157839.0
# Transport, storage, communication & services related to broadcasting     10680267.0
# Financial services                                                        6205000.0
# Real estate, ownership of dwelling & professional services               15763846.0
# Public administration                                                     9367218.0
# ...

# %%
agg_gsdp=gsva.loc[category3,'Gross State Domestic Product'].sum()
agg_gsdp
# Out:
# 182402227.0

# %%
round(100*agg/agg_gsdp).sort_values(ascending=False).head().plot.bar()    #percentage

# %%
agg=gsva.loc[category4,categories_col].sum()
agg_gsdp=gsva.loc[category4,'Gross State Domestic Product'].sum()
round(100*agg/agg_gsdp).sort_values(ascending=False).head().plot.bar()    #percentage

# %%
drop_out_rate=pd.read_csv(r"D:\CSV\rs_session243_au570_1.1.csv",index_col=0)
drop_out_rate
# Out:
#           Level of Education - State  Primary - 2012-2013  \
# Sl. No.
# 1                      A & N Islands                 0.68
# 2                     Andhra Pradesh                 3.18
# 3                  Arunachal Pradesh                15.16
# 4                              Assam                 6.24
# 5                              Bihar                  NaN
# 6                         Chandigarh                  NaN
# 7                        Chhatisgarh                 4.14
# 8               Dadra & Nagar Haveli                  NaN
# 9                        Daman & Diu                  NaN
# 10                             Delhi                  NaN
# 11                               Goa                  NaN
# 12                           Gujarat                 0.74
# 13                           Haryana                 1.29
# 14                  Himachal Pradesh                 0.45
# 15                 Jammu and Kashmir                 6.30
# ...

# %%
drop_out_rate.rename(columns={"Level of Education - State":"State"},inplace=True)

# %%
drop_out_rate.replace({"Andhra Pradesh":"Andhra_Pradesh","Arunachal Pradesh":"Arunachal_Pradesh",
                      "Uttar Pradesh":"Uttar_Pradesh","Madhya Pradesh":"Madhya_Pradesh"})
# Out:
#                           State  Primary - 2012-2013  Primary - 2014-2015  \
# Sl. No.
# 1                 A & N Islands                 0.68                 1.21
# 2                Andhra_Pradesh                 3.18                 4.35
# 3             Arunachal_Pradesh                15.16                10.89
# 4                         Assam                 6.24                 7.44
# 5                         Bihar                  NaN                 2.09
# 6                    Chandigarh                  NaN                  NaN
# 7                   Chhatisgarh                 4.14                 1.42
# 8          Dadra & Nagar Haveli                  NaN                 1.57
# 9                   Daman & Diu                  NaN                 0.85
# 10                        Delhi                  NaN                  NaN
# 11                          Goa                  NaN                 0.20
# ...

# %%
drop_out_rate=drop_out_rate.set_index("State")
drop_out_rate
# Out:
#                       Primary - 2012-2013  Primary - 2014-2015  \
# State
# A & N Islands                        0.68                 1.21
# Andhra Pradesh                       3.18                 4.35
# Arunachal Pradesh                   15.16                10.89
# Assam                                6.24                 7.44
# Bihar                                 NaN                 2.09
# Chandigarh                            NaN                  NaN
# Chhatisgarh                          4.14                 1.42
# Dadra & Nagar Haveli                  NaN                 1.57
# Daman & Diu                           NaN                 0.85
# Delhi                                 NaN                  NaN
# Goa                                   NaN                 0.20
# Gujarat                              0.74                 0.76
# Haryana                              1.29                 0.41
# Himachal Pradesh                     0.45                 0.46
# ...

# %%
gsva_drop=pd.merge(gsva,drop_out_rate,how="inner",left_index=True,right_index=True)
gsva_drop.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
gsva_primary=gsva_drop[["Per Capita GSDP (Rs.)","Primary - 2014-2015"]]

# %%
gsva_primary.dropna(inplace=True)
# Out:
# <ipython-input-52-aa07bd18a071>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva_primary.dropna(inplace=True)

# %%
gsva_primary["Primary - 2014-2015"]=gsva_primary["Primary - 2014-2015"].astype(int)
# Out:
# <ipython-input-53-e70c13897b75>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva_primary["Primary - 2014-2015"]=gsva_primary["Primary - 2014-2015"].astype(int)

# %%
gsva_primary
# Out:
#             Per Capita GSDP (Rs.)  Primary - 2014-2015
# Tripura                     77358                    3
# Telangana                  139035                    5
# Sikkim                     240274                    4
# Rajasthan                   84837                    8
# Punjab                     126606                    1
# Odisha                      73979                    2
# Nagaland                    89607                   19
# Meghalaya                   76228                   10
# Manipur                     58442                   18
# Maharashtra                152853                    0
# Karnataka                  145141                    2
# Jharkhand                   62091                    6
# Haryana                    164077                    0
# Gujarat                    141263                    0
# Goa                        271793                    0
# Bihar                       33954                    2
# ...

# %%
import matplotlib.pyplot as plt

# %%
gsva_primary.plot.scatter(x="Per Capita GSDP (Rs.)",y="Primary - 2014-2015")    #1

# %%
plt.scatter(x=gsva_primary["Per Capita GSDP (Rs.)"],y=gsva_primary["Primary - 2014-2015"])    #the same can write   2

# %%
gsva_sec=gsva_drop[["Per Capita GSDP (Rs.)","Secondary - 2014-2015"]]
gsva_sec.dropna(inplace=True)
# Out:
# <ipython-input-59-467a86dbec7a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva_sec.dropna(inplace=True)

# %%
gsva_sec["Secondary - 2014-2015"]=gsva_sec["Secondary - 2014-2015"].astype(int)
gsva_sec
# Out:
# <ipython-input-62-d1f66656a961>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gsva_sec["Secondary - 2014-2015"]=gsva_sec["Secondary - 2014-2015"].astype(int)
#             Per Capita GSDP (Rs.)  Secondary - 2014-2015
# Tripura                     77358                     28
# Telangana                  139035                     15
# Sikkim                     240274                     15
# Rajasthan                   84837                     13
# Punjab                     126606                      8
# Odisha                      73979                     29
# Nagaland                    89607                     18
# Meghalaya                   76228                     20
# ...

# %%
gsva_sec.plot.scatter(x="Per Capita GSDP (Rs.)",y="Secondary - 2014-2015")
